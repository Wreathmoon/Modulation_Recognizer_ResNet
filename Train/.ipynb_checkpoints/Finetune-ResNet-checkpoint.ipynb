# %%
import os
import gc
import json
import h5py
import keras
import random
import matplotlib
import numpy as np
import seaborn as sns
import scipy.io as sio
import scipy.io.wavfile
import tensorflow as tf
import matplotlib.pyplot as plt

from keras import layers
from keras.models import Model
from keras.regularizers import *
from keras.optimizers import adam_v2
from keras.callbacks import TensorBoard, EarlyStopping
from keras import metrics, regularizers, optimizers, backend
from keras.layers import Reshape,ZeroPadding2D,Flatten,Activation
from keras.layers import Flatten,pooling,AlphaDropout,MaxPooling2D
from keras.layers import Input,Dense,Dropout,BatchNormalization,Conv2D

os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# ## 读数据

# %%
'''由于内存有限，原始数据集从 2555904x1024x2 抽取到 374400x1024x2
（600*26*24，24种调制，26个信噪比，每个信号IQ两组数据）。
而且提取的数据集也被分成24个部分，分多次读取以节省内存'''

classes = ['32PSK', '16APSK', '32QAM', 'FM', 'GMSK', '32APSK', 'OQPSK',
           '8ASK', 'BPSK', '8PSK', 'AM-SSB-SC', '4ASK', '16PSK', '64APSK',
           '128QAM', '128APSK', 'AM-DSB-SC', 'AM-SSB-WC', '64QAM', 'QPSK',
           '256QAM', 'AM-DSB-WC', 'OOK','16QAM']

for i in range(0,24):  #分24次读取
    
    filename = r'C:\Users\xuluo\Desktop\Modulation\Dataset\ExtractDataset\part'+str(i) + '.h5'
    f = h5py.File(filename,'r')
    
    # x为信号数据，y是标签（24种调制），z是信噪比标签
    x_temp = f["X"][:]
    y_temp = f["Y"][:]
    z_temp = f["Z"][:]
    f.close()       #读完就关，节省内存
    
    if i == 0:
        x_data = x_temp
        y_data = y_temp
        z_data = z_temp
    else:           #把之后读的数据拼起来
        x_data = np.vstack((x_data, x_temp))
        y_data = np.vstack((y_data, y_temp))
        z_data = np.vstack((z_data, z_temp))

# %% [markdown]
# ## 打乱 & 划分数据集验证集测试集

# %%
# 只抽取信噪比大于0的信号数据来进行训练
data_idx_allSNRs = [i for i in range(x_data.shape[0])]
data_idx = [i for i in data_idx_allSNRs if list(z_data[i])[0] >= 0] 

# 全部读取后再进行打乱index
random.shuffle(data_idx)

x_data = x_data[data_idx]
y_data = y_data[data_idx]
z_data = z_data[data_idx]

# 划分训练集，验证集，测试集。8：1：1
total_num = x_data.shape[0]
train_num = int(total_num * 0.8)   # 先把训练集随机划出来
train_idx = np.random.choice(range(0,total_num), size=train_num, replace=False)
val_test_idx = list(set(range(0,total_num))-set(train_idx))  

x_train = x_data[train_idx]
y_train = y_data[train_idx]
z_train = z_data[train_idx]
x_val_test = x_data[val_test_idx]
y_val_test = y_data[val_test_idx]
z_val_test = z_data[val_test_idx]

val_test_num = x_val_test.shape[0]
val_num = int(val_test_num * 0.5)  # 再1：1随机划验证集和测试集
val_idx = np.random.choice(range(0,val_test_num), size=val_num, replace=False)
test_idx = list(set(range(0,val_test_num))-set(val_idx)) 

x_val = x_val_test[val_idx]
y_val = y_val_test[val_idx]
z_val = z_val_test[val_idx]
x_test = x_val_test[test_idx]
y_test = y_val_test[test_idx]
z_test = z_val_test[test_idx]

# 观测数据集的shape
print('train of x：',x_train.shape)
print('train of y：',y_train.shape)
print('train of z：',z_train.shape)
print('val of x：',x_val.shape)
print('val of y：',y_val.shape)
print('val of z：',z_val.shape)
print('test of x：',x_test.shape)
print('test of y：',y_test.shape)
print('test of z：',z_test.shape)
# Out:
# train of x： (184320, 1024, 2)
# train of y： (184320, 24)
# train of z： (184320, 1)
# val of x： (23040, 1024, 2)
# val of y： (23040, 24)
# val of z： (23040, 1)
# test of x： (23040, 1024, 2)
# test of y： (23040, 24)
# test of z： (23040, 1)

# %% [markdown]
# ## ResNet 模型

# %%
filepath_weights =  r'C:\Users\xuluo\Desktop\Modulation\Train\Weights\ResNet_weights_067-0.861_SNRover0.h5'
finetune_model = keras. models.load_model(filepath_weights)
adam = keras.optimizers.adam_v2.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
finetune_model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['categorical_accuracy'])

# %%
num_classes = 8

x = finetune_model.layers[-3].output
predictions = Dense(num_classes, activation='softmax', name="dense_train")(x)
    
model = Model(inputs=finetune_model.input, outputs=predictions)

for layer in model.layers[:-3]:
    layer.trainable = False
for layer in model.layers[-3:]:
    layer.trainable = True
    
model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1024, 2)]    0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1024, 2)   0           input_1[0][0]
# __________________________________________________________________________________________________
# ReStk0_conv1 (Conv2D)           (None, 32, 1024, 2)  64          reshape[0][0]
# __________________________________________________________________________________________________
# ReStk0_conv2 (Conv2D)           (None, 32, 1024, 2)  6176        ReStk0_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk0_conv3 (Conv2D)           (None, 32, 1024, 2)  6176        ReStk0_conv2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 1024, 2)  0           ReStk0_conv3[0][0]
#                                                                  ReStk0_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 1024, 2)  0           add[0][0]
# __________________________________________________________________________________________________
# ReStk0_conv4 (Conv2D)           (None, 32, 1024, 2)  6176        activation[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 1024, 2)  0           ReStk0_conv4[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 1024, 2)  0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 512, 1)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv1 (Conv2D)           (None, 32, 512, 1)   1056        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv2 (Conv2D)           (None, 32, 512, 1)   3104        ReStk1_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv3 (Conv2D)           (None, 32, 512, 1)   3104        ReStk1_conv2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 512, 1)   0           ReStk1_conv3[0][0]
#                                                                  ReStk1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 512, 1)   0           add_2[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv4 (Conv2D)           (None, 32, 512, 1)   3104        activation_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 512, 1)   0           ReStk1_conv4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 512, 1)   0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 256, 1)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv1 (Conv2D)           (None, 32, 256, 1)   1056        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv2 (Conv2D)           (None, 32, 256, 1)   3104        ReStk2_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv3 (Conv2D)           (None, 32, 256, 1)   3104        ReStk2_conv2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 256, 1)   0           ReStk2_conv3[0][0]
#                                                                  ReStk2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 256, 1)   0           add_4[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv4 (Conv2D)           (None, 32, 256, 1)   3104        activation_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 256, 1)   0           ReStk2_conv4[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 256, 1)   0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 128, 1)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv1 (Conv2D)           (None, 32, 128, 1)   1056        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv2 (Conv2D)           (None, 32, 128, 1)   3104        ReStk3_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv3 (Conv2D)           (None, 32, 128, 1)   3104        ReStk3_conv2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 128, 1)   0           ReStk3_conv3[0][0]
#                                                                  ReStk3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 128, 1)   0           add_6[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv4 (Conv2D)           (None, 32, 128, 1)   3104        activation_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 128, 1)   0           ReStk3_conv4[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 128, 1)   0           add_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 64, 1)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv1 (Conv2D)           (None, 32, 64, 1)    1056        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv2 (Conv2D)           (None, 32, 64, 1)    3104        ReStk4_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv3 (Conv2D)           (None, 32, 64, 1)    3104        ReStk4_conv2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 64, 1)    0           ReStk4_conv3[0][0]
#                                                                  ReStk4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 64, 1)    0           add_8[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv4 (Conv2D)           (None, 32, 64, 1)    3104        activation_8[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 64, 1)    0           ReStk4_conv4[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 64, 1)    0           add_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 1)    0           activation_9[0][0]
# __________________________________________________________________________________________________
# ReStk5_conv1 (Conv2D)           (None, 32, 32, 1)    1056        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# ReStk5_conv2 (Conv2D)           (None, 32, 32, 1)    3104        ReStk5_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk5_conv3 (Conv2D)           (None, 32, 32, 1)    3104        ReStk5_conv2[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 1)    0           ReStk5_conv3[0][0]
#                                                                  ReStk5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 1)    0           add_10[0][0]
# __________________________________________________________________________________________________
# ReStk5_conv4 (Conv2D)           (None, 32, 32, 1)    3104        activation_10[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 1)    0           ReStk5_conv4[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 1)    0           add_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 16, 1)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 128)          65664       flatten[0][0]
# __________________________________________________________________________________________________
# alpha_dropout (AlphaDropout)    (None, 128)          0           dense1[0][0]
# __________________________________________________________________________________________________
# dense_train (Dense)             (None, 8)            1032        alpha_dropout[0][0]
# ==================================================================================================
# Total params: 137,128
# Trainable params: 66,696
# Non-trainable params: 70,432
# __________________________________________________________________________________________________

# %% [markdown]
# ## 训练

# %%
print(tf.test.gpu_device_name()) # 看显卡
print('Start Traning:')
filepath = r'C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep{epoch:03d}_{val_categorical_accuracy:.3f}.h5'
filepath_weights =  r'C:\Users\xuluo\Desktop\Modulation\Train\Weights\ResNet_weights_018-acc0.78_SNRover0.h5'

# 当连续 10 次迭代准确度不再增加时停止
earlystop = keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy', patience=10, verbose=1, mode='auto')

# 保存准确度最高时的权值和模型
ckpt = keras.callbacks.ModelCheckpoint(filepath, monitor='val_categorical_accuracy',verbose=1, save_best_only=True, mode='auto')

# 从之前的检查点加载并继续训练
# resnet_model = keras.models.load_model(filepath_weights) 

finetune_train = finetune_model.fit(x_train,
                                    y_train,
                                    batch_size=256,   # 不爆内存的最大batch size了
                                    epochs=100,       # 一般跑不完就收敛了
                                    verbose=1,
                                    validation_data=(x_val, y_val),
                                    callbacks = [ckpt,earlystop])
# Out:
# /device:GPU:0
# Start Traning:
# Epoch 1/100
# 720/720 [==============================] - 117s 145ms/step - loss: 1.4740 - categorical_accuracy: 0.4278 - val_loss: 1.2387 - val_categorical_accuracy: 0.5114
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.51141, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep001_0.511.h5
# Epoch 2/100
# C:\Users\xuluo\.conda\envs\work\lib\site-packages\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 720/720 [==============================] - 105s 146ms/step - loss: 1.0357 - categorical_accuracy: 0.5614 - val_loss: 0.8943 - val_categorical_accuracy: 0.6149
#
# Epoch 00002: val_categorical_accuracy improved from 0.51141 to 0.61489, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep002_0.615.h5
# Epoch 3/100
# 720/720 [==============================] - 105s 146ms/step - loss: 0.9037 - categorical_accuracy: 0.6108 - val_loss: 0.8776 - val_categorical_accuracy: 0.6391
#
# Epoch 00003: val_categorical_accuracy improved from 0.61489 to 0.63911, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep003_0.639.h5
# Epoch 4/100
# 720/720 [==============================] - 106s 147ms/step - loss: 0.8255 - categorical_accuracy: 0.6415 - val_loss: 0.7622 - val_categorical_accuracy: 0.6737
#
# Epoch 00004: val_categorical_accuracy improved from 0.63911 to 0.67365, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep004_0.674.h5
# Epoch 5/100
# 720/720 [==============================] - 105s 146ms/step - loss: 0.7526 - categorical_accuracy: 0.6676 - val_loss: 0.7934 - val_categorical_accuracy: 0.6820
#
# Epoch 00005: val_categorical_accuracy improved from 0.67365 to 0.68199, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep005_0.682.h5
# Epoch 6/100
# 720/720 [==============================] - 104s 145ms/step - loss: 0.6982 - categorical_accuracy: 0.6891 - val_loss: 0.6631 - val_categorical_accuracy: 0.7180
#
# Epoch 00006: val_categorical_accuracy improved from 0.68199 to 0.71797, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep006_0.718.h5
# Epoch 7/100
# 720/720 [==============================] - 104s 145ms/step - loss: 0.6609 - categorical_accuracy: 0.7038 - val_loss: 0.6428 - val_categorical_accuracy: 0.7148
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.71797
# Epoch 8/100
# 720/720 [==============================] - 104s 145ms/step - loss: 0.6302 - categorical_accuracy: 0.7167 - val_loss: 0.6846 - val_categorical_accuracy: 0.7201
#
# Epoch 00008: val_categorical_accuracy improved from 0.71797 to 0.72010, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep008_0.720.h5
# Epoch 9/100
# 720/720 [==============================] - 105s 146ms/step - loss: 0.6184 - categorical_accuracy: 0.7216 - val_loss: 0.6281 - val_categorical_accuracy: 0.7356
#
# Epoch 00009: val_categorical_accuracy improved from 0.72010 to 0.73563, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep009_0.736.h5
# Epoch 10/100
# 720/720 [==============================] - 104s 145ms/step - loss: 0.5894 - categorical_accuracy: 0.7343 - val_loss: 0.6659 - val_categorical_accuracy: 0.7406
#
# Epoch 00010: val_categorical_accuracy improved from 0.73563 to 0.74058, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep010_0.741.h5
# Epoch 11/100
# 720/720 [==============================] - 103s 144ms/step - loss: 0.5661 - categorical_accuracy: 0.7477 - val_loss: 0.6208 - val_categorical_accuracy: 0.7394
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.74058
# Epoch 12/100
# 720/720 [==============================] - 104s 144ms/step - loss: 0.5398 - categorical_accuracy: 0.7593 - val_loss: 0.5124 - val_categorical_accuracy: 0.7789
#
# Epoch 00012: val_categorical_accuracy improved from 0.74058 to 0.77895, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep012_0.779.h5
# Epoch 13/100
# 720/720 [==============================] - 104s 145ms/step - loss: 0.5138 - categorical_accuracy: 0.7700 - val_loss: 0.4754 - val_categorical_accuracy: 0.7900
#
# Epoch 00013: val_categorical_accuracy improved from 0.77895 to 0.78997, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep013_0.790.h5
# Epoch 14/100
# 720/720 [==============================] - 103s 144ms/step - loss: 0.4945 - categorical_accuracy: 0.7770 - val_loss: 0.4972 - val_categorical_accuracy: 0.7852
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.78997
# Epoch 15/100
# 720/720 [==============================] - 103s 144ms/step - loss: 0.4789 - categorical_accuracy: 0.7845 - val_loss: 0.4808 - val_categorical_accuracy: 0.7977
#
# Epoch 00015: val_categorical_accuracy improved from 0.78997 to 0.79774, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep015_0.798.h5
# Epoch 16/100
# 720/720 [==============================] - 103s 144ms/step - loss: 0.4681 - categorical_accuracy: 0.7907 - val_loss: 0.4861 - val_categorical_accuracy: 0.7999
#
# Epoch 00016: val_categorical_accuracy improved from 0.79774 to 0.79987, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep016_0.800.h5
# Epoch 17/100
# 720/720 [==============================] - 104s 144ms/step - loss: 0.4547 - categorical_accuracy: 0.7958 - val_loss: 0.5001 - val_categorical_accuracy: 0.7950
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.79987
# Epoch 18/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.4457 - categorical_accuracy: 0.8025 - val_loss: 0.4986 - val_categorical_accuracy: 0.7957
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.79987
# Epoch 19/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.4459 - categorical_accuracy: 0.8027 - val_loss: 0.4694 - val_categorical_accuracy: 0.8075
#
# Epoch 00019: val_categorical_accuracy improved from 0.79987 to 0.80751, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep019_0.808.h5
# Epoch 20/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.4276 - categorical_accuracy: 0.8145 - val_loss: 0.4729 - val_categorical_accuracy: 0.8122
#
# Epoch 00020: val_categorical_accuracy improved from 0.80751 to 0.81220, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep020_0.812.h5
# Epoch 21/100
# 720/720 [==============================] - 102s 142ms/step - loss: 0.4230 - categorical_accuracy: 0.8174 - val_loss: 0.5015 - val_categorical_accuracy: 0.8034
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.81220
# Epoch 22/100
# 720/720 [==============================] - 102s 142ms/step - loss: 0.4160 - categorical_accuracy: 0.8209 - val_loss: 0.4251 - val_categorical_accuracy: 0.8247
#
# Epoch 00022: val_categorical_accuracy improved from 0.81220 to 0.82470, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep022_0.825.h5
# Epoch 23/100
# 720/720 [==============================] - 102s 142ms/step - loss: 0.4160 - categorical_accuracy: 0.8232 - val_loss: 0.4338 - val_categorical_accuracy: 0.8302
#
# Epoch 00023: val_categorical_accuracy improved from 0.82470 to 0.83016, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep023_0.830.h5
# Epoch 24/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3919 - categorical_accuracy: 0.8326 - val_loss: 0.4482 - val_categorical_accuracy: 0.8333
#
# Epoch 00024: val_categorical_accuracy improved from 0.83016 to 0.83329, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep024_0.833.h5
# Epoch 25/100
# 720/720 [==============================] - 103s 144ms/step - loss: 0.3885 - categorical_accuracy: 0.8368 - val_loss: 0.4210 - val_categorical_accuracy: 0.8383
#
# Epoch 00025: val_categorical_accuracy improved from 0.83329 to 0.83828, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep025_0.838.h5
# Epoch 26/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3867 - categorical_accuracy: 0.8371 - val_loss: 0.4380 - val_categorical_accuracy: 0.8368
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.83828
# Epoch 27/100
# 720/720 [==============================] - 104s 144ms/step - loss: 0.3678 - categorical_accuracy: 0.8470 - val_loss: 0.3882 - val_categorical_accuracy: 0.8490
#
# Epoch 00027: val_categorical_accuracy improved from 0.83828 to 0.84905, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep027_0.849.h5
# Epoch 28/100
# 720/720 [==============================] - 103s 144ms/step - loss: 0.3632 - categorical_accuracy: 0.8488 - val_loss: 0.4755 - val_categorical_accuracy: 0.8348
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.84905
# Epoch 29/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3647 - categorical_accuracy: 0.8482 - val_loss: 0.4046 - val_categorical_accuracy: 0.8522
#
# Epoch 00029: val_categorical_accuracy improved from 0.84905 to 0.85217, saving model to C:\Users\xuluo\Desktop\Modulation\Train\ResNet_weights_ep029_0.852.h5
# Epoch 30/100
# 720/720 [==============================] - 103s 142ms/step - loss: 0.3499 - categorical_accuracy: 0.8543 - val_loss: 0.4254 - val_categorical_accuracy: 0.8419
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.85217
# Epoch 31/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3492 - categorical_accuracy: 0.8551 - val_loss: 0.3990 - val_categorical_accuracy: 0.8489
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.85217
# Epoch 32/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3421 - categorical_accuracy: 0.8578 - val_loss: 0.4219 - val_categorical_accuracy: 0.8450
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.85217
# Epoch 33/100
# 720/720 [==============================] - 102s 142ms/step - loss: 0.3414 - categorical_accuracy: 0.8584 - val_loss: 0.4528 - val_categorical_accuracy: 0.8355
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.85217
# Epoch 34/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3331 - categorical_accuracy: 0.8626 - val_loss: 0.3962 - val_categorical_accuracy: 0.8520
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.85217
# Epoch 35/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3266 - categorical_accuracy: 0.8653 - val_loss: 0.4190 - val_categorical_accuracy: 0.8461
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.85217
# Epoch 36/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3304 - categorical_accuracy: 0.8643 - val_loss: 0.4386 - val_categorical_accuracy: 0.8445
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.85217
# Epoch 37/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3260 - categorical_accuracy: 0.8651 - val_loss: 0.4387 - val_categorical_accuracy: 0.8464
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.85217
# Epoch 38/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3288 - categorical_accuracy: 0.8652 - val_loss: 0.4637 - val_categorical_accuracy: 0.8464
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.85217
# Epoch 39/100
# 720/720 [==============================] - 103s 143ms/step - loss: 0.3193 - categorical_accuracy: 0.8692 - val_loss: 0.4083 - val_categorical_accuracy: 0.8454
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.85217
# Epoch 00039: early stopping

# %% [markdown]
# ## 画整个训练中损失函数和准确性的变化图

# %%
plt.figure(figsize=(8,3)) 

# 保存损失和准确性值到txt
val_loss_list = resnet_train.history['val_loss']
loss_list = resnet_train.history['loss']
categorical_accuracy = resnet_train.history['categorical_accuracy']
val_categorical_accuracy = resnet_train.history['val_categorical_accuracy']

# 续写模式 不覆盖之前的数据
with open(r"C:\Users\xuluo\Desktop\Modulation\Train\Weights\loss_acc_data.txt","w") as txt:
    txt.write('\n'+f'val_loss_list loss_list categorical_accuracy val_categorical_accuracy'+'\n')
    for i in range(len(loss_list)):
        txt.write(f'{val_loss_list[i]} {loss_list[i]} {categorical_accuracy[i]} {val_categorical_accuracy[i]}\n')
    txt.close()

# 并列着画
ax1=plt.subplot(121)
# 蓝色是训练集的 红色是验证集的
plt.plot(range(len(loss_list)),val_loss_list,color='red',label='val_loss')
plt.plot(range(len(loss_list)),loss_list,color='blue',label='train_loss')

ax2 = plt.subplot(122)
plt.plot(range(len(categorical_accuracy)),categorical_accuracy,color='blue',label='train_accuracy')
plt.plot(range(len(categorical_accuracy)),val_categorical_accuracy,color='red',label='val_accuracy')

plt.show()

# %% [markdown]
# ## 加载表现最好的重量值

# %%
filepath_weights =  r'C:\Users\xuluo\Desktop\Modulation\Train\Weights\ResNet_weights_067-0.861_SNRover0.h5'
model = keras. models.load_model(filepath_weights)

# %% [markdown]
# ## 测试集上进行测试

# %%
# 预测值
y_test_pd = model.predict(x_test, batch_size=1024)

conf = np.zeros([len(classes),len(classes)])
confnorm = np.zeros([len(classes),len(classes)])

# j为实际调制类别，k为预测的
for i in range(0,x_test.shape[0]):
    j = list(y_test[i,:]).index(1)
    k = int(np.argmax(y_test_pd[i,:]))
    conf[j,k] = conf[j,k] + 1
    
# 归为0到1的概率
for i in range(0,len(classes)):
    confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])

# %% [markdown]
# ## 画各调制信号的分类准确度

# %%
# jk对角线即为该类别的预测准确度
classes_pd = np.array([round(confnorm[i,i],4) for i in range(len(confnorm))])

temp1_classes_pd = classes_pd[:]
temp2_classes_pd = [int(temp1_classes_pd[i]*10000) for i in range(len(temp1_classes_pd))]

# 按准确度排序
sort_index = np.argsort(temp2_classes_pd)
classes = np.array(classes)
classes_sort = classes[sort_index]
classes_pd_sort = classes_pd[sort_index]

fig,ax = plt.subplots()
# 横着画柱状图
a = plt.barh(range(len(classes_sort)),classes_pd_sort,color='#6699CC')
for x in a:
    width = x.get_width()
    # 标注准确度百分比
    plt.text(width, x.get_y()+x.get_height()/2,'{:.2f}%'.format(width*100), ha='left',va='center',fontsize=8)
ax.set_yticks(range(len(classes_sort)))
ax.set_yticklabels(classes_sort)
plt.title('Categorical Accuracy of Classes', loc='center', fontsize='15',fontweight='bold')

plt.show()

# %% [markdown]
# ## 画信噪比和准确度的关系图

# %%
acc={}
classes = list(classes)
z_test_snr = z_test.reshape((len(z_test)))
# 信噪比种类
SNRs = np.unique(z_test_snr)

for snr in SNRs:
    # 取当前信噪比的信号和标注数据
    x_test_snr = x_test[z_test_snr==snr]
    y_test_snr = y_test[z_test_snr==snr]
    
    # 预测
    y_test_snr_pd = model.predict(x_test_snr)
    conf = np.zeros([len(classes),len(classes)])
    confnorm = np.zeros([len(classes),len(classes)])
    
    # 方法同上
    for i in range(0,x_test_snr.shape[0]):    
        j = list(y_test_snr[i,:]).index(1)   
        j = classes.index(classes[j])
        k = int(np.argmax(y_test_snr_pd[i,:])) 
        k = classes.index(classes[k])
        conf[j,k] = conf[j,k] + 1
   
    acc_eachSNR = np.sum(np.diag(conf))
    not_acc_eachSNR = np.sum(conf) - acc_eachSNR
    print ("Accuracy at %sdB: %.4f"%(snr, acc_eachSNR / (acc_eachSNR+not_acc_eachSNR)))
    # 储存为字典
    acc[snr] = 1.0*acc_eachSNR / (acc_eachSNR+not_acc_eachSNR)
    
plt.plot(acc.keys(),acc.values())
plt.ylabel('Acc')
plt.xlabel('SNRs')
plt.show()
# Out:
# Accuracy at 0dB: 0.5989
# Accuracy at 2dB: 0.6700
# Accuracy at 4dB: 0.7726
# Accuracy at 6dB: 0.8420
# Accuracy at 8dB: 0.9130
# Accuracy at 10dB: 0.9346
# Accuracy at 12dB: 0.9460
# Accuracy at 14dB: 0.9563
# Accuracy at 16dB: 0.9563
# Accuracy at 18dB: 0.9550
# Accuracy at 20dB: 0.9577
# Accuracy at 22dB: 0.9537
# Accuracy at 24dB: 0.9459
# Accuracy at 26dB: 0.9541
# Accuracy at 28dB: 0.9561
# Accuracy at 30dB: 0.9614

# %% [markdown]
# ## 指定信号 Index

# %%
type_want = 'BPSK'

classes = np.array(['32PSK', '16APSK', '32QAM', 'FM', 'GMSK', '32APSK', 'OQPSK',
           '8ASK', 'BPSK', '8PSK', 'AM-SSB-SC', '4ASK', '16PSK', '64APSK',
           '128QAM', '128APSK', 'AM-DSB-SC', 'AM-SSB-WC', '64QAM', 'QPSK',
           '256QAM', 'AM-DSB-WC', 'OOK','16QAM'])
y_want = np.array(np.zeros(classes.shape[0])) 
y_want[np.where(classes == type_want)[0][0]] = 1

index_want_list = []
for i in range(0,x_test.shape[0]):
    if all(y_test[i] == y_want):
        index_want_list.append(i)
        
index_want = index_want_list[np.random.choice(range(0,len(index_want_list)), size=1, replace=False)[0]]
print(index_want)
# Out:
# 22644

# %% [markdown]
# ## 单个信号的预测演示

# %%
# 测试集中随意抽取一组信号
test_id = np.random.choice(range(0,x_test.shape[0]), size=1, replace=False) 

# 或是指定信号id
index_want = index_want_list[np.random.choice(range(0,len(index_want_list)), size=1, replace=False)[0]]
test_id = np.array([index_want])

print(x_test[test_id].shape)
y_test_guess = model.predict(x_test[test_id])

class_real = classes[list(y_test[test_id][0]).index(1)]
class_guess = classes[int(np.argmax(y_test_guess[0,:]))]

# 输出预测结果
print('Signal Noise Ratio:',z_test[test_id][0][0],' dB')
print('Modulation Type is',class_real,'| Prediction is',class_guess,'| Guess is ',class_real==class_guess)

plt_data = x_test[test_id].T
plt.figure(figsize=(15,5))
plt.plot(plt_data[0],color = 'green')
plt.plot(plt_data[1],color = 'brown')

plt.show()
# Out:
# (1, 1024, 2)
# Signal Noise Ratio: 4  dB
# Modulation Type is BPSK | Prediction is BPSK | Guess is  True

# %% [markdown]
# ## 真实信号的处理与预测

# %% [markdown]
# ## 拉伸函数 & 缩小函数

# %%
def stretch(data_input):
    data_input_T = data_input[:,:int(data_input.shape[1]/2),:].T
    data_output = np.zeros((2,2*data_input_T.shape[1],1))
    for i in range(data_output.shape[1]):
        if i%2 == 0:
            data_output[0][i] = data_input_T[0][int(i/2)]
            data_output[1][i] = data_input_T[1][int(i/2)]
        elif (i == data_output.shape[1]-1):
            data_output[0][i] = data_input_T[0][data_input_T.shape[1]-1]
            data_output[1][i] = data_input_T[1][data_input_T.shape[1]-1]
        else:
            data_output[0][i] = (data_input_T[0][int((i+1)/2)]+data_input_T[0][int((i-1)/2)])/2
            data_output[1][i] = (data_input_T[1][int((i+1)/2)]+data_input_T[1][int((i-1)/2)])/2
    data_output = data_output.T
    return data_output

def multi_stretch(n,data_i):
    if n == 0:
        return data_i
    return multi_stretch(n-1,stretch(data_i))

def shrink(data_big):
    data_temp = data_big.T
    data_small = np.zeros((2,1024,1))
    for i in range(data_temp.shape[0]):
        for j in range(data_temp.shape[1]):
            data_small[i][j] = float(data_temp[i][j]/1000)
    return data_small.T

# %%
filepath_signal = r'C:\Users\xuluo\Desktop\Modulation\Sample Signal'
filepath_8PSK_ = [r'\8PSK\8PSK_30000_38400_20220701_101223_10k.wav',r'\8PSK\8PSK_30000_38400_20220701_101428_20k.wav',
                  r'\8PSK\8PSK_200000_256000_20220701_101613_30k.wav',r'\8PSK\8PSK_200000_256000_20220701_101702_35k.wav',
                  r'\8PSK\8PSK_200000_256000_20220701_101755_50k.wav']
filepath_64QAM_ = [r'\64QAM\64QAM_30000_38400_20220701_143323_10k.wav',r'\64QAM\64QAM_200000_256000_20220701_143749_50k.wav',
                   r'\64QAM\64QAM_30000_38400_20220701_143551_20k.wav',r'\64QAM\64QAM_200000_256000_20220701_143713_30k.wav']
filepath_BPSK_ = [r'\BPSK\BPSK_30000_38400_20220630_174450_10k_symbolrate.wav',r'\BPSK\BPSK_30000_38400_20220630_174726_20k_symbolrate.wav',
                  r'\BPSK\BPSK_200000_256000_20220630_174850_30k_symbolrate.wav',r'\BPSK\BPSK_200000_256000_20220630_175135_50k_symbolrate.wav',
                  r'\BPSK\BPSK_200000_256000_20220630_175038_35k_symbolrate.wav',r'\BPSK\BPSK_200000_256000_20220630_175319_20k_symbolrate.wav',]
filepath_OQPSK_ = [r'\OQPSK\OQPSK_30000_38400_20220701_093651_10k.wav',r'\OQPSK\OQPSK_30000_38400_20220701_093830_20k.wav',
                   r'\OQPSK\OQPSK_200000_256000_20220701_094307_30k.wav',r'\OQPSK\OQPSK_200000_256000_20220701_094408_35k.wav',
                   r'\OQPSK\OQPSK_200000_256000_20220701_094505_50k.wav']
filepath_QPSK_ = [r'\QPSK\QPSK_30000_38400_20220630_175531_10k.wav',r'\QPSK\QPSK_30000_38400_20220630_175647_20k.wav',
                  r'\QPSK\QPSK_200000_256000_20220701_091540_30k.wav',r'\QPSK\QPSK_200000_256000_20220701_091718_35k.wav',
                  r'\QPSK\QPSK_200000_256000_20220701_091815_50k.wav']

filepath_8PSK = filepath_signal + random.choice(filepath_8PSK_)     # cool
filepath_64QAM = filepath_signal + random.choice(filepath_64QAM_)   # perfect except 32
filepath_BPSK = filepath_signal + random.choice(filepath_BPSK_)     # not good
filepath_OQPSK = filepath_signal + random.choice(filepath_OQPSK_)   # not good
filepath_QPSK = filepath_signal + random.choice(filepath_QPSK_)     # # not good



filepath = filepath_BPSK
rate, data_raw = scipy.io.wavfile.read(filepath, mmap=False)
print(rate)
print(filepath_8PSK[47:])
data = np.expand_dims(data_raw,axis=0)
slice = int(np.random.choice(range(0,data.shape[1]-1024), size=1, replace=False))
data_slice = data[:,slice:(slice+1024),:]

## Stretch n times
stretched_times = 1
data_stretched = multi_stretch(stretched_times,data_slice)

## Choose which one
if filepath[47:].split("_")[2] == '38400':
    data_final_1 = data_stretched
elif filepath[47:].split("_")[2] == '256000':
    data_final_1 = data_slice

## Shrink
data_final = shrink(data_final_1)

y_real_guess = model.predict(data_final)
class_guess_real = classes[int(np.argmax(y_real_guess[0,:]))]

sort_prob = np.argsort(-y_real_guess[0,:])
print("\nThe modulation is likely to be:")
for i in range(5):
    print('{0} {1:.3f}'.format(classes[sort_prob][i],y_real_guess[0,:][sort_prob][i]))


# 输出预测结果
print('\nPrediction is',class_guess_real)
plt_data = data_final.T
plt.figure(figsize=(15,5))
plt.plot(plt_data[0],color = 'green')
plt.plot(plt_data[1],color = 'brown')

plt.show()
# Out:
# C:\Users\xuluo\.conda\envs\work\lib\site-packages\ipykernel_launcher.py:26: WavFileWarning: Reached EOF prematurely; finished at 4679804 bytes, expected 4679848 bytes from header.
# 38400
# \8PSK\8PSK_200000_256000_20220701_101613_30k.wav
#
# The modulation is likely to be:
# 64QAM 0.999
# 32QAM 0.001
# AM-SSB-WC 0.000
# 16APSK 0.000
# QPSK 0.000
#
# Prediction is 64QAM
